# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime
from os import path
import os 
import xlrd
import sys 
import glob

# %%
cedir = os.path.dirname(os.path.abspath(sys.argv[0]))
cedir
# Out:
# '/Applications/anaconda3/lib/python3.8/site-packages'

# %%
x = pd.read_csv('/Users/brunopimentel/Documents/GitHub/MyST/files//NAFTRAC_20180131.csv', 
                skiprows=2)
x
# Out:
#         Ticker                              Nombre Clase de activo  Peso (%)  \
# 0         AMXL                     AMERICA MOVIL L          Equity     13.31
# 1     FEMSAUBD          FOMENTO ECONOMICO MEXICANO          Equity     12.69
# 2     GFNORTEO                 GPO FINANCE BANORTE          Equity      9.51
# 3      WALMEX*                 WALMART DE MEXICO V          Equity      7.60
# 4     GMEXICOB                      GRUPO MEXICO B          Equity      7.54
# 5     CEMEXCPO                           CEMEX CPO          Equity      7.44
# 6   TLEVISACPO                      GRUPO TELEVISA          Equity      6.21
# 7        ALFAA                              ALFA A          Equity      2.68
# 8         GAPB  GRUPO AEROPORTUARIO DEL PACIFICO O          Equity      2.51
# 9        ASURB   GRUPO AEROPORTUARIO DEL SURESTE B          Equity      2.44
# 10        KOFL             COCA-COLA FEMSA CLASS L          Equity      2.42
# ...

# %%
x.T.iloc[0]
# Out:
# 0           AMXL
# 1       FEMSAUBD
# 2       GFNORTEO
# 3        WALMEX*
# 4       GMEXICOB
# 5       CEMEXCPO
# 6     TLEVISACPO
# 7          ALFAA
# 8           GAPB
# 9          ASURB
# 10          KOFL
# 11        BIMBOA
# 12      MEXCHEM*
# 13           AC*
# 14      GFINBURO
# 15       IENOVA*
# 16         BSMXB
# 17       KIMBERA
# 18        GRUMAB
# 19      ELEKTRA*
# 20       PINFRA*
# 21      PE&OLES*
# 22          OMAB
# 23      GCARSOA1
# 24    LIVEPOLC.1
# 25       MEGACPO
# 26        ALSEA*
# 27       CUERVO*
# 28      GENTERA*
# 29         LALAB
# 30        VOLARA
# 31          LABB
# 32      GFREGIOO
# 33        ALPEKA
# 34        NEMAKA
# 35           MXN
# 36
# Name: Ticker, dtype: object
